# %% [markdown]
# # Importing Required Libraries and Reading Data

# %%
import pandas as pd

# %%
# Reading CSV file into a DataFrame
df=pd.read_csv("/Users/srijanagella/Documents/Airline_review.csv")
# Displaying a random sample of 20 rows from the DataFrame
df.sample(20)
# Out:
#        Unnamed: 0              Airline Name Overall_Rating  \
# 15552       15552                  Onur Air              4
# 15082       15082                   Nok Air              1
# 1760         1760                Air France              6
# 4472         4472                AnadoluJet              7
# 2750         2750                Air Serbia              1
# 15422       15422               Olympic Air              8
# 4440         4440    ANA All Nippon Airways              1
# 12316       12316           Jetstar Airways              1
# 3965         3965                  Alitalia              2
# 6133         6133         Brussels Airlines              1
# 12506       12506             Jetstar Japan              1
# 8219         8219           Eastern Airways              9
# 8955         8955            Etihad Airways              1
# 15831       15831          Pegasus Airlines              2
# 4734         4734               Aurigny Air              1
# 11835       11835            Japan Airlines              9
# 3299         3299             AirAsia India              8
# 2940         2940            Air Tahiti Nui              5
# 5526         5526  Beijing Capital Airlines              1
# 4293         4293            American Eagle              1
#
#                                      Review_Title         Review Date  \
# 15552                   "otherwise I would avoid"  2nd September 2015
# 15082         "flight cancelled the night before"  17th February 2019
# 1760          "The in flight experience was fine"     9th August 2022
# 4472                   AnadoluJet customer review      21st July 2013
# 2750           "twice the flights were cancelled"   13th January 2022
# 15422                 Olympic Air customer review  31st December 2009
# 4440          "best ANA flight attendant service"      19th June 2019
# 12316     "left my 15 year old daughter stranded"        2nd May 2023
# 3965                           "the rudest staff"       24th May 2019
# 6133                   "such an arrogant company"      6th April 2023
# 12506                  "Every flight was perfect"  17th December 2019
# 8219              Eastern Airways customer review   31st January 2012
# 8955                 "the service was a disaster"      4th March 2023
# 15831                  "Would never recommend it"  22nd February 2022
# 4734                  Aurigny Air customer review  10th December 2014
# 11835  "this airline deserves a five-star review"   16th January 2021
# 3299               "One of the best experiences "      10th June 2019
# 2940               Air Tahiti Nui customer review       21st May 2014
# 5526        "not informed of flight cancellation"    8th October 2015
# 4293                    "the ghetto of airplanes"  20th December 2018
#
#        Verified                                             Review  \
# 15552     False  Very small seats and drinks were not free. Boa...
# 15082      True    We purchased 4 tickets from Bangkok to Phuke...
# 1760       True    We were able to fit everything into carry on...
# 4472      False  Flight Antalya to Ankara flight on time pleasa...
# 2750       True    Air Serbia show flights which have already b...
# 15422     False  AMS-ATH return. New Airbus aircraft friendly a...
# 4440       True    Jakarta to Tokyo Narita. I love ANA, is the ...
# 12316     False    If I could give no stars I would. Seriously ...
# 3965      False    Montenegro to Cairo via Rome. Worst airline ...
# 6133       True    Brussels Airlines sells you a seat and then,...
# 12506      True    Tokyo to Fukuoka via Osaka. Four domestic fl...
# 8219      False  Newcastle - Cardiff same day return. Flights l...
# 8955       True    Abu Dhabi to Amsterdam, the boarding process...
# 15831      True    Would never recommend it. No service no mana...
# 4734      False  I flew GCI-LGW-GCI in November. 5 minutes earl...
# 11835      True    Excellent food for an airplane choice. Excel...
# 3299      False    Kolkata to Bangalore. Amazing quality. One o...
# 2940      False  The seats were so uncomfortable I was dreading...
# 5526      False  Departed from Singapore and arrived in Beijing...
# 4293       True    Kansas City via Dallas Ft Worth operated by ...
#
#              Aircraft Type Of Traveller        Seat Type  \
# 15552             NaN    Couple Leisure    Economy Class
# 15082             NaN    Couple Leisure    Economy Class
# 1760       Boeing 777    Family Leisure    Economy Class
# 4472              NaN               NaN    Economy Class
# 2750              NaN          Business   Business Class
# 15422             NaN               NaN    Economy Class
# 4440     Boeing 787-8    Family Leisure    Economy Class
# 12316             NaN      Solo Leisure    Economy Class
# 3965              NaN    Family Leisure    Economy Class
# 6133             A320    Family Leisure    Economy Class
# 12506            A320      Solo Leisure    Economy Class
# 8219              NaN               NaN    Economy Class
# 8955      Boeing 787     Couple Leisure    Economy Class
# 15831  Boeing 737-800    Family Leisure    Economy Class
# 4734              NaN               NaN    Economy Class
# 11835      Boeing 777      Solo Leisure    Economy Class
# 3299             A320    Family Leisure    Economy Class
# 2940              NaN               NaN    Economy Class
# 5526              NaN      Solo Leisure    Economy Class
# 4293              NaN          Business  Premium Economy
#
#                                  Route     Date Flown  Seat Comfort  \
# 15552              Dalaman to Istanbul    August 2015           1.0
# 15082                Bangkok to Phuket  November 2018           1.0
# 1760             New York to Paris CDG      July 2022           3.0
# 4472                               NaN            NaN           4.0
# 2750      Zurich to Sofia via Belgrade   January 2022           NaN
# 15422                              NaN            NaN           NaN
# 4440           Jakarta to Tokyo Narita     March 2019           5.0
# 12316             Adelaide to Brisbane       May 2023           1.0
# 3965      Montenegro to Cairo via Rome       May 2019           4.0
# 6133                Geneva to Brussels     April 2023           NaN
# 12506       Tokyo to Fukuoka via Osaka  December 2019           5.0
# 8219                               NaN            NaN           NaN
# 8955            Abu Dhabi to Amsterdam     March 2023           1.0
# 15831            Stuttgart to Istanbul  February 2022           2.0
# 4734                               NaN            NaN           NaN
# 11835      Chicago to Manila via Tokyo  December 2020           5.0
# 3299              Kolkata to Bangalore      June 2019           4.0
# 2940                               NaN            NaN           1.0
# 5526                 Beijing to Hailar    August 2015           NaN
# 4293   Kansas City via Dallas Ft Worth  December 2018           1.0
#
#        Cabin Staff Service  Food & Beverages  Ground Service  \
# 15552                  3.0               1.0             1.0
# 15082                  1.0               NaN             1.0
# 1760                   3.0               3.0             2.0
# 4472                   3.0               1.0             NaN
# 2750                   NaN               NaN             NaN
# 15422                  NaN               NaN             NaN
# 4440                   5.0               5.0             5.0
# 12316                  1.0               1.0             1.0
# 3965                   2.0               3.0             1.0
# 6133                   NaN               NaN             NaN
# 12506                  5.0               5.0             5.0
# 8219                   NaN               NaN             NaN
# 8955                   1.0               1.0             2.0
# 15831                  2.0               2.0             1.0
# 4734                   NaN               NaN             NaN
# 11835                  5.0               5.0             5.0
# 3299                   5.0               2.0             2.0
# 2940                   4.0               4.0             NaN
# 5526                   NaN               NaN             1.0
# 4293                   1.0               1.0             1.0
#
#        Inflight Entertainment  Wifi & Connectivity  Value For Money  \
# 15552                     NaN                  NaN              3.0
# 15082                     NaN                  NaN              1.0
# 1760                      4.0                  NaN              4.0
# 4472                      1.0                  NaN              4.0
# 2750                      NaN                  NaN              1.0
# 15422                     NaN                  NaN              4.0
# 4440                      5.0                  4.0              4.0
# 12316                     1.0                  1.0              1.0
# 3965                      NaN                  NaN              2.0
# 6133                      NaN                  NaN              1.0
# 12506                     NaN                  NaN              5.0
# 8219                      NaN                  NaN              1.0
# 8955                      3.0                  1.0              1.0
# 15831                     1.0                  1.0              2.0
# 4734                      NaN                  NaN              4.0
# 11835                     5.0                  4.0              5.0
# 3299                      NaN                  NaN              3.0
# 2940                      3.0                  NaN              3.0
# 5526                      NaN                  NaN              1.0
# 4293                      NaN                  NaN              1.0
#
#       Recommended
# 15552          no
# 15082          no
# 1760          yes
# 4472          yes
# 2750           no
# 15422         yes
# 4440          yes
# 12316          no
# 3965           no
# 6133           no
# 12506         yes
# 8219          yes
# 8955           no
# 15831          no
# 4734          yes
# 11835         yes
# 3299          yes
# 2940           no
# 5526           no
# 4293           no

# %%
#!pip install scikit-learn

# %% [markdown]
# # Preprocessing and Sentiment Analysis

# %%
# Importing the preprocessing module from the scikit-learn library
from sklearn import preprocessing
# Importing the Natural Language Toolkit (NLTK)
import nltk
# Downloading the opinion lexicon dataset from NLTK
nltk.download('opinion_lexicon')
# Importing the opinion_lexicon dataset from the NLTK corpus module
from nltk.corpus import opinion_lexicon
# Importing the word_tokenize function from the NLTK tokenize module
from nltk.tokenize import word_tokenize
# Printing the total number of words in the opinion_lexicon dataset
print('Total number of words in opinion lexicon', len(opinion_lexicon.words()))
# Printing examples of positive words in the opinion_lexicon dataset
print('Examples of positive words in opinion lexicon',
      opinion_lexicon.positive()[:10])
# Printing examples of negative words in the opinion_lexicon dataset
print('Examples of negative words in opinion lexicon',
      opinion_lexicon.negative()[:10])
# Out:
# Total number of words in opinion lexicon 6789
# Examples of positive words in opinion lexicon ['a+', 'abound', 'abounds', 'abundance', 'abundant', 'accessable', 'accessible', 'acclaim', 'acclaimed', 'acclamation']
# Examples of negative words in opinion lexicon ['2-faced', '2-faces', 'abnormal', 'abolish', 'abominable', 'abominably', 'abominate', 'abomination', 'abort', 'aborted']
# [nltk_data] Downloading package opinion_lexicon to
# [nltk_data]     /Users/srijanagella/nltk_data...
# [nltk_data]   Package opinion_lexicon is already up-to-date!

# %% [markdown]
# # Data Preparation and Scoring

# %%
# Let's create a dictionary which we can use for scoring our review text

# Downloading punkt from NLTK library
nltk.download('punkt')

# Renaming the column 'reviewText' to 'Modules' in the DataFrame
df.rename(columns={"reviewText": "Modules"}, inplace=True)

# Assigning positive and negative scores
pos_score = 1
neg_score = -1

# Initializing an empty dictionary
word_dict = {}
 
# Adding the positive words to the dictionary
for word in opinion_lexicon.positive():
        word_dict[word] = pos_score
      
# Adding the negative words to the dictionary
for word in opinion_lexicon.negative():
        word_dict[word] = neg_score
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/srijanagella/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#Creating a fuunction text
def bing_liu_score(Modules):
    #Initializing the sentiment score
    sentiment_score = 0
    #Tokenizing the input text into words and convert them to lowercase
    bag_of_words = word_tokenize(Modules.lower())
     # creating loop to check each word in the bag of words
    for word in bag_of_words:
        #Checking if the word exists in the sentiment dictionary
        if word in word_dict:
            # If the word exist, adding its sentiment score to the sentiment score
            sentiment_score += word_dict[word]
    return sentiment_score  #Returning the sentiment score for the text

# %%
# Fill NaN values in the 'Review' column
df['Review'].fillna('no review', inplace=True)
#creating new column 'Bing_Liu_Score' to store the scores by applying  bing_liu_score to calculate sentiment scores for Review column
df['Bing_Liu_Score'] = df['Review'].apply(bing_liu_score)

# %% [markdown]
# # Analysis and Visualization

# %%
# Displaying the first 5 rows of the DataFrame with few columns
df[['Airline Name',"Overall_Rating","Review", 'Bing_Liu_Score']].head(5)
# Out:
#     Airline Name Overall_Rating  \
# 0    AB Aviation              9
# 1    AB Aviation              1
# 2    AB Aviation              1
# 3  Adria Airways              1
# 4  Adria Airways              1
#
#                                               Review  Bing_Liu_Score
# 0    Moroni to Moheli. Turned out to be a pretty ...               7
# 1   Moroni to Anjouan. It is a very small airline...              -3
# 2    Anjouan to Dzaoudzi. A very small airline an...               2
# 3    Please do a favor yourself and do not fly wi...              -6
# 4   Do not book a flight with this airline! My fr...              -2

# %%
# Grouping the DataFrame by the 'Airline Name' column and calculating the mean of 'Bing_Liu_Score' for each group
df.groupby('Airline Name').agg({'Bing_Liu_Score':'mean'})
# Out:
#                         Bing_Liu_Score
# Airline Name
# AB Aviation                   2.000000
# ANA All Nippon Airways        5.290000
# ASKY Airlines                -1.956522
# ATA Airlines                 -0.500000
# Adria Airways                 2.648352
# ...                                ...
# euroAtlantic Airways         -0.187500
# fastjet                       0.030303
# flyadeal                     -2.684211
# flybe                         0.750000
# flydubai                     -2.060000
#
# [497 rows x 1 columns]

# %%
# Grouping the DataFrame by the 'Overall_Rating' column and calculating the mean of 'Bing_Liu_Score' for each group
df.groupby('Overall_Rating').agg({'Bing_Liu_Score':'mean'})
# Out:
#                 Bing_Liu_Score
# Overall_Rating
# 1                    -0.881501
# 2                    -1.891551
# 3                    -1.196903
# 4                     0.038417
# 5                     1.137349
# 6                     1.909630
# 7                     3.670578
# 8                     4.628913
# 9                     5.162330
# n                     0.606888

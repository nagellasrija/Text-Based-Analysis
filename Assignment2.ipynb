# %% [markdown]
# # Installing Pandas Using Pip

# %%
pip install pandas  #Install Pandas using pip
# Out:
# Requirement already satisfied: pandas in /Users/srijanagella/anaconda3/lib/python3.11/site-packages (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/srijanagella/anaconda3/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/srijanagella/anaconda3/lib/python3.11/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/srijanagella/anaconda3/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in /Users/srijanagella/anaconda3/lib/python3.11/site-packages (from pandas) (1.24.3)
# Requirement already satisfied: six>=1.5 in /Users/srijanagella/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Reading CSV File Into a DataFrame

# %%
import pandas as pd  #import pandas alias pd
df = pd.read_csv('/Users/srijanagella/Documents/Airline_review.csv') # Read the CSV file into a DataFrame, replace the path with your correct path

# %%
df.head(20)  #Displaying the First 20 Rows of a DataFrame
# Out:
#     Unnamed: 0   Airline Name Overall_Rating  \
# 0            0    AB Aviation              9
# 1            1    AB Aviation              1
# 2            2    AB Aviation              1
# 3            3  Adria Airways              1
# 4            4  Adria Airways              1
# 5            5  Adria Airways              1
# 6            6  Adria Airways              1
# 7            7  Adria Airways              1
# 8            8  Adria Airways              1
# 9            9  Adria Airways              8
# 10          10  Adria Airways              1
# 11          11  Adria Airways              1
# 12          12  Adria Airways              2
# 13          13  Adria Airways              2
# 14          14  Adria Airways              3
# 15          15  Adria Airways              1
# 16          16  Adria Airways              1
# 17          17  Adria Airways              3
# 18          18  Adria Airways              9
# 19          19  Adria Airways              2
#
#                                Review_Title          Review Date  Verified  \
# 0                   "pretty decent airline"   11th November 2019      True
# 1                      "Not a good airline"       25th June 2019      True
# 2            "flight was fortunately short"       25th June 2019      True
# 3       "I will never fly again with Adria"  28th September 2019     False
# 4     "it ruined our last days of holidays"  24th September 2019      True
# 5                 "Had very bad experience"  17th September 2019      True
# 6          "worse than the budget airlines"   6th September 2019     False
# 7                    "book another company"     24th August 2019     False
# 8                    "combined two flights"      6th August 2019      True
# 9                       "the crew was nice"    12th October 2018      True
# 10            "Very bad experience overall"     5th October 2018     False
# 11                   "bad customer service"       29th July 2018      True
# 12                      "overall very poor"       19th July 2018      True
# 13                    "Would not fly again"       30th June 2018      True
# 14             "very unpleasant experience"       24th June 2018      True
# 15            "Flight was very comfortable"         4th May 2018      True
# 16          "delayed for more than 2 hours"      11th March 2018      True
# 17  "should be ashamed of their operations"    5th December 2017      True
# 18                 "Two nice short flights"   20th November 2017      True
# 19                  "extremely bad service"    27th October 2017     False
#
#                                                Review        Aircraft  \
# 0     Moroni to Moheli. Turned out to be a pretty ...             NaN
# 1    Moroni to Anjouan. It is a very small airline...            E120
# 2     Anjouan to Dzaoudzi. A very small airline an...   Embraer E120
# 3     Please do a favor yourself and do not fly wi...             NaN
# 4    Do not book a flight with this airline! My fr...             NaN
# 5     Had very bad experience with rerouted and ca...          CR 900
# 6     Ljubljana to Zürich. Firstly, Ljubljana airp...             NaN
# 7     First of all, I am not complaining about a s...  Bombardier CRJ
# 8     Worst Airline ever! They combined two flight...             NaN
# 9    Ljubljana to Munich. The homebase airport of ...             NaN
# 10    Zurich to Ljubljana. Very poor customer serv...             NaN
# 11    Vienna to Sofia. The flight was delayed by 2...             NaN
# 12    We were traveling from Paris to Skopje on Ma...             NaN
# 13    Ljubljana to Munich. Adria's checkin system ...             NaN
# 14    A very unpleasant experience for my family. ...            A319
# 15    Frankfurt to Ljubljana. Flight was very comf...             NaN
# 16    Ljubljana to Frankfurt. Flight delayed for m...             NaN
# 17    Ljubljana to Vienna. Overall, the flight ser...          ATR-72
# 18   Two nice short flights from Ljubljana to Sara...  CRJ700 / ATR72
# 19   We were 11 people coming in with a short conn...             NaN
#
#    Type Of Traveller      Seat Type                             Route  \
# 0       Solo Leisure  Economy Class                  Moroni to Moheli
# 1       Solo Leisure  Economy Class                 Moroni to Anjouan
# 2       Solo Leisure  Economy Class               Anjouan to Dzaoudzi
# 3       Solo Leisure  Economy Class             Frankfurt to Pristina
# 4     Couple Leisure  Economy Class  Sofia to Amsterdam via Ljubljana
# 5     Couple Leisure  Economy Class             Sarajevo to Ljubljana
# 6           Business  Economy Class               Ljubljana to Zürich
# 7       Solo Leisure  Economy Class               Timisoara to Munich
# 8       Solo Leisure  Economy Class  Pristina to Zürich via Ljubliana
# 9     Family Leisure  Economy Class               Ljubljana to Munich
# 10          Business  Economy Class               Zurich to Ljubljana
# 11    Family Leisure  Economy Class                   Vienna to Sofia
# 12      Solo Leisure  Economy Class     Paris to Skopje via Ljubljana
# 13          Business  Economy Class               Ljubljana to Munich
# 14    Couple Leisure  Economy Class               Ljubljana to Prague
# 15          Business  Economy Class            Frankfurt to Ljubljana
# 16      Solo Leisure  Economy Class            Ljubljana to Frankfurt
# 17      Solo Leisure  Economy Class               Ljubljana to Vienna
# 18          Business  Economy Class             Ljubljana to Sarajevo
# 19    Couple Leisure  Economy Class                Zurich to Ljubjana
#
#         Date Flown  Seat Comfort  Cabin Staff Service  Food & Beverages  \
# 0    November 2019           4.0                  5.0               4.0
# 1        June 2019           2.0                  2.0               1.0
# 2        June 2019           2.0                  1.0               1.0
# 3   September 2019           1.0                  1.0               NaN
# 4   September 2019           1.0                  1.0               1.0
# 5   September 2019           1.0                  1.0               1.0
# 6   September 2019           1.0                  1.0               1.0
# 7      August 2019           1.0                  1.0               1.0
# 8      August 2019           1.0                  2.0               1.0
# 9     October 2018           4.0                  4.0               3.0
# 10    October 2018           2.0                  1.0               NaN
# 11       July 2018           4.0                  1.0               1.0
# 12        May 2018           3.0                  3.0               NaN
# 13       June 2018           1.0                  2.0               2.0
# 14       June 2018           3.0                  3.0               NaN
# 15      April 2018           5.0                  5.0               5.0
# 16      March 2018           2.0                  1.0               1.0
# 17  September 2017           2.0                  4.0               1.0
# 18   November 2017           5.0                  5.0               3.0
# 19    October 2017           3.0                  3.0               NaN
#
#     Ground Service  Inflight Entertainment  Wifi & Connectivity  \
# 0              4.0                     NaN                  NaN
# 1              1.0                     NaN                  NaN
# 2              1.0                     NaN                  NaN
# 3              1.0                     NaN                  NaN
# 4              1.0                     1.0                  1.0
# 5              1.0                     1.0                  1.0
# 6              1.0                     NaN                  NaN
# 7              1.0                     1.0                  1.0
# 8              1.0                     1.0                  1.0
# 9              5.0                     NaN                  NaN
# 10             1.0                     1.0                  1.0
# 11             4.0                     NaN                  NaN
# 12             3.0                     NaN                  NaN
# 13             2.0                     NaN                  NaN
# 14             1.0                     NaN                  NaN
# 15             5.0                     NaN                  NaN
# 16             1.0                     1.0                  1.0
# 17             1.0                     NaN                  NaN
# 18             5.0                     NaN                  NaN
# 19             1.0                     NaN                  NaN
#
#     Value For Money Recommended
# 0               3.0         yes
# 1               2.0          no
# 2               2.0          no
# 3               1.0          no
# 4               1.0          no
# 5               1.0          no
# 6               1.0          no
# 7               1.0          no
# 8               1.0          no
# 9               5.0         yes
# 10              1.0          no
# 11              1.0          no
# 12              2.0          no
# 13              1.0          no
# 14              1.0          no
# 15              5.0         yes
# 16              1.0          no
# 17              3.0          no
# 18              3.0         yes
# 19              1.0          no

# %% [markdown]
# # Displaying Column Names

# %%
df.columns # Display column names
# Out:
# Index(['Unnamed: 0', 'Airline Name', 'Overall_Rating', 'Review_Title',
#        'Review Date', 'Verified', 'Review', 'Aircraft', 'Type Of Traveller',
#        'Seat Type', 'Route', 'Date Flown', 'Seat Comfort',
#        'Cabin Staff Service', 'Food & Beverages', 'Ground Service',
#        'Inflight Entertainment', 'Wifi & Connectivity', 'Value For Money',
#        'Recommended'],
#       dtype='object')

# %% [markdown]
# # Printing Data Types of the Columns

# %%
# Printing Data Types of the Columns
df.dtypes
# Out:
# Unnamed: 0                  int64
# Airline Name               object
# Overall_Rating             object
# Review_Title               object
# Review Date                object
# Verified                     bool
# Review                     object
# Aircraft                   object
# Type Of Traveller          object
# Seat Type                  object
# Route                      object
# Date Flown                 object
# Seat Comfort              float64
# Cabin Staff Service       float64
# Food & Beverages          float64
# Ground Service            float64
# Inflight Entertainment    float64
# Wifi & Connectivity       float64
# Value For Money           float64
# Recommended                object
# dtype: object

# %% [markdown]
# # Printing Basic Information of the Data Set

# %%
# Printing the Basic Information of the Data Set.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23171 entries, 0 to 23170
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              23171 non-null  int64
#  1   Airline Name            23171 non-null  object
#  2   Overall_Rating          23171 non-null  object
#  3   Review_Title            23171 non-null  object
#  4   Review Date             23171 non-null  object
#  5   Verified                23171 non-null  bool
#  6   Review                  23171 non-null  object
#  7   Aircraft                7129 non-null   object
#  8   Type Of Traveller       19433 non-null  object
#  9   Seat Type               22075 non-null  object
#  10  Route                   19343 non-null  object
#  11  Date Flown              19417 non-null  object
#  12  Seat Comfort            19016 non-null  float64
#  13  Cabin Staff Service     18911 non-null  float64
#  14  Food & Beverages        14500 non-null  float64
#  15  Ground Service          18378 non-null  float64
#  16  Inflight Entertainment  10829 non-null  float64
#  17  Wifi & Connectivity     5920 non-null   float64
#  18  Value For Money         22105 non-null  float64
#  19  Recommended             23171 non-null  object
# dtypes: bool(1), float64(7), int64(1), object(11)
# memory usage: 3.4+ MB

# %% [markdown]
# # Printing the Statistical Information of the Data Set

# %%
# Printing the Statistical Information of the Data Set.
df.describe()
# Out:
#         Unnamed: 0  Seat Comfort  Cabin Staff Service  Food & Beverages  \
# count  23171.00000  19016.000000         18911.000000      14500.000000
# mean   11585.00000      2.618374             2.871609          2.553586
# std     6689.03588      1.464840             1.604631          1.526314
# min        0.00000      0.000000             0.000000          0.000000
# 25%     5792.50000      1.000000             1.000000          1.000000
# 50%    11585.00000      3.000000             3.000000          2.000000
# 75%    17377.50000      4.000000             4.000000          4.000000
# max    23170.00000      5.000000             5.000000          5.000000
#
#        Ground Service  Inflight Entertainment  Wifi & Connectivity  \
# count    18378.000000            10829.000000          5920.000000
# mean         2.353738                2.179056             1.780405
# std          1.595747                1.488839             1.318800
# min          1.000000                0.000000             0.000000
# 25%          1.000000                1.000000             1.000000
# 50%          1.000000                2.000000             1.000000
# 75%          4.000000                3.000000             2.000000
# max          5.000000                5.000000             5.000000
#
#        Value For Money
# count     22105.000000
# mean          2.451165
# std           1.594155
# min           0.000000
# 25%           1.000000
# 50%           2.000000
# 75%           4.000000
# max           5.000000

# %% [markdown]
# # Adding a New Column to Store Length of the Text

# %%
# Adding a new column to store length of the text.
df['length']=df['Review'].str.len()
df.describe()
# Out:
#         Unnamed: 0  Seat Comfort  Cabin Staff Service  Food & Beverages  \
# count  23171.00000  19016.000000         18911.000000      14500.000000
# mean   11585.00000      2.618374             2.871609          2.553586
# std     6689.03588      1.464840             1.604631          1.526314
# min        0.00000      0.000000             0.000000          0.000000
# 25%     5792.50000      1.000000             1.000000          1.000000
# 50%    11585.00000      3.000000             3.000000          2.000000
# 75%    17377.50000      4.000000             4.000000          4.000000
# max    23170.00000      5.000000             5.000000          5.000000
#
#        Ground Service  Inflight Entertainment  Wifi & Connectivity  \
# count    18378.000000            10829.000000          5920.000000
# mean         2.353738                2.179056             1.780405
# std          1.595747                1.488839             1.318800
# min          1.000000                0.000000             0.000000
# 25%          1.000000                1.000000             1.000000
# 50%          1.000000                2.000000             1.000000
# 75%          4.000000                3.000000             2.000000
# max          5.000000                5.000000             5.000000
#
#        Value For Money        length
# count     22105.000000  23171.000000
# mean          2.451165    721.819084
# std           1.594155    537.620659
# min           0.000000     14.000000
# 25%           1.000000    361.000000
# 50%           2.000000    561.000000
# 75%           4.000000    904.500000
# max           5.000000   5080.000000

# %% [markdown]
# # Using describe Method

# %%
# Using describe Method
df.describe(include='O')
# Out:
#               Airline Name Overall_Rating              Review_Title  \
# count                23171          23171                     23171
# unique                 497             10                     17219
# top     Caribbean Airlines              1  Onur Air customer review
# freq                   100          11595                        84
#
#            Review Date                                             Review  \
# count            23171                                              23171
# unique            4557                                              23046
# top     16th July 2023  I spend at least the half of my time during a ...
# freq                67                                                  2
#
#        Aircraft Type Of Traveller      Seat Type                Route  \
# count      7129             19433          22075                19343
# unique     1048                 4              4                13607
# top        A320      Solo Leisure  Economy Class  Melbourne to Sydney
# freq       1041              7120          19145                   43
#
#        Date Flown Recommended
# count       19417       23171
# unique        109           2
# top     June 2023          no
# freq         1057       15364

# %% [markdown]
# # Data Visualization

# %%
# Importing matplotlib Package
import matplotlib.pyplot as plt
# Assuming 'length' as a Target Column
df['length'].plot(label='Length')
# Adding legend
plt.xlabel('Length')
plt.ylabel('Frequency')
plt.legend()
# Display the plot
plt.show()

# %% [markdown]
# # Ploting a Box Plot

# %%
df['length'].plot(kind='box', vert=False)
# Adding labels and title
plt.xlabel('Length')
plt.title('Horizontal Box Plot of Length')
# Showing the plot
plt.show()

# %% [markdown]
# # Histogram

# %%
# Creating a Histogram
df['length'].plot(kind='hist',bins=30)
plt.xlabel('Length')
# Out:
# Text(0.5, 0, 'Length')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='Seat Comfort', bins=30, kde=True)
plt.title('Distribution of Seat Comfort')
plt.xlabel('Seat Comfort')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # Installing Regex Package

# %%
# !pip install regex
# Out:
# Requirement already satisfied: regex in /Users/srijanagella/anaconda3/lib/python3.11/site-packages (2022.7.9)

# %% [markdown]
# # Using Regex to Pull Out Words

# %%
# Regex to Pull Out Words
import regex as re
def tokenize(text):return re.findall(r'[\w-]*[a-z|A-Z][\w-]*', text) # Function To Tokenize

# %%
# Toknizing the Given Text
testtext = "Let's defeat SARS-CoV-2 together in 2020! www.cdc.gov"
testtokens = tokenize(testtext)
print(testtokens)
# Out:
# ['Let', 's', 'defeat', 'SARS-CoV-2', 'together', 'in', 'www', 'cdc', 'gov']

# %% [markdown]
# # Installing NLTK Package

# %%
# Installing nltk Package
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /Users/srijanagella/anaconda3/lib/python3.11/site-packages (3.8.1)
# Requirement already satisfied: click in /Users/srijanagella/anaconda3/lib/python3.11/site-packages (from nltk) (8.0.4)
# Requirement already satisfied: joblib in /Users/srijanagella/anaconda3/lib/python3.11/site-packages (from nltk) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /Users/srijanagella/anaconda3/lib/python3.11/site-packages (from nltk) (2022.7.9)
# Requirement already satisfied: tqdm in /Users/srijanagella/anaconda3/lib/python3.11/site-packages (from nltk) (4.65.0)

# %%
import nltk  # Importing nltk Package
from nltk.tokenize import word_tokenize

nltk.download('punkt') 
nltk.download('stopwords')
# Downloading list of English Stop Words
stopwords = set(nltk.corpus.stopwords.words('english'))  
print(stopwords)
# Out:
# {'ll', 'below', 'these', 'will', 'itself', "wasn't", 'some', "she's", 'doing', 'to', 'were', 'after', 'whom', 'how', 'under', 'any', "won't", 'been', 'by', 'too', "shouldn't", "mustn't", 'him', 'with', 'further', 'which', 'nor', 'be', 'just', 'is', 'yours', 'shouldn', 'wasn', 'should', 'ma', 'hers', "didn't", "isn't", 'where', 'them', 'was', 'only', 'can', 'no', 'such', 'an', "should've", 'who', 'but', 'being', 'are', 'our', 'don', 'into', 'and', 'he', 'through', 'not', 'mustn', 'then', 'their', 't', 'myself', "mightn't", "that'll", 'in', 'doesn', 'theirs', 'hasn', "you're", 'very', "haven't", 'when', 'does', 'shan', 'this', 'here', 'so', 'her', 'that', "you'd", "you've", 'o', "you'll", 'most', 'as', 'you', "needn't", 'out', 'herself', 'haven', 'at', 'why', 'up', 'ain', 'has', 's', "doesn't", 'we', 'ourselves', 'himself', 'my', 'did', 'own', 'few', "aren't", "hadn't", 'over', 've', 'both', 'about', 'its', 'am', 'weren', 'off', 'your', 'didn', 'if', 'ours', 're', "wouldn't", 'than', 'had', "weren't", 'hadn', 'the', 'other', 'there', 'because', 'won', 'of', 'against', 'yourself', 'they', 'now', 'more', 'same', 'couldn', 'down', 'yourselves', "hasn't", 'isn', 'his', 'what', 'on', 'd', 'aren', 'from', 'while', 'those', 'all', 'between', 'do', 'have', 'for', 'i', 'or', 'once', 'during', 'wouldn', "couldn't", "it's", 'before', "shan't", 'm', 'y', 'having', 'it', 'me', 'she', 'until', 'above', 'each', 'again', 'themselves', 'needn', 'mightn', 'a', "don't"}
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/srijanagella/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/srijanagella/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# # Making a Pipeline

# %%
# making a “pipeline"
pipeline = [str.lower, tokenize]
def prepare(text, pipeline):
    tokens = text
    for fun in pipeline:
        tokens = fun(tokens)
    return tokens

# %%
# Runing the pipeline
df['tokens'] = df['Review'].apply(prepare, pipeline=pipeline)

# %%
#counting the tokens
df['num_tokens'] = df['tokens'].dropna().map(len)
df.tail()
# Out:
#        Unnamed: 0 Airline Name Overall_Rating  \
# 23166       23166       ZIPAIR              1
# 23167       23167       ZIPAIR              1
# 23168       23168       ZIPAIR              3
# 23169       23169       ZIPAIR              6
# 23170       23170       ZIPAIR              1
#
#                                  Review_Title    Review Date  Verified  \
# 23166          "customer service is terrible"  5th July 2022     False
# 23167                    "Avoid at all costs"  1st June 2022      True
# 23168          "Will not recommend to anyone"  31st May 2022      True
# 23169             "It was immaculately clean"  23rd May 2022      True
# 23170  "lost all of our money with no refund"  20th May 2022      True
#
#                                                   Review    Aircraft  \
# 23166   Bangkok to Tokyo. I’ve flown many low cost ai...         NaN
# 23167    Avoid at all costs. I booked flights to go f...         NaN
# 23168    Flight was leaving at 23.15 and after an hou...         NaN
# 23169   Zipair is JAL’s budget airline. They don’t ha...  Dreamliner
# 23170    They lied about connection in Narita and we ...         NaN
#
#       Type Of Traveller       Seat Type  ... Cabin Staff Service  \
# 23166    Couple Leisure   Economy Class  ...                 1.0
# 23167      Solo Leisure   Economy Class  ...                 NaN
# 23168          Business   Economy Class  ...                 4.0
# 23169          Business  Business Class  ...                 4.0
# 23170      Solo Leisure   Economy Class  ...                 NaN
#
#       Food & Beverages  Ground Service  Inflight Entertainment  \
# 23166              NaN             1.0                     1.0
# 23167              NaN             NaN                     NaN
# 23168              2.0             1.0                     NaN
# 23169              3.0             1.0                     2.0
# 23170              NaN             1.0                     NaN
#
#        Wifi & Connectivity  Value For Money  Recommended  length  \
# 23166                  1.0              1.0           no     803
# 23167                  NaN              1.0           no     777
# 23168                  NaN              2.0           no     906
# 23169                  5.0              5.0          yes    3109
# 23170                  NaN              1.0           no     294
#
#                                                   tokens num_tokens
# 23166  [bangkok, to, tokyo, i, ve, flown, many, low, ...        140
# 23167  [avoid, at, all, costs, i, booked, flights, to...        139
# 23168  [flight, was, leaving, at, and, after, an, hou...        163
# 23169  [zipair, is, jal, s, budget, airline, they, do...        584
# 23170  [they, lied, about, connection, in, narita, an...         52
#
# [5 rows x 23 columns]

# %% [markdown]
# # Counting Token Occurrences

# %%
#counting the tokens
df['num_tokens'] = df['tokens'].dropna().map(len)
df.tail()
# Out:
#        Unnamed: 0 Airline Name Overall_Rating  \
# 23166       23166       ZIPAIR              1
# 23167       23167       ZIPAIR              1
# 23168       23168       ZIPAIR              3
# 23169       23169       ZIPAIR              6
# 23170       23170       ZIPAIR              1
#
#                                  Review_Title    Review Date  Verified  \
# 23166          "customer service is terrible"  5th July 2022     False
# 23167                    "Avoid at all costs"  1st June 2022      True
# 23168          "Will not recommend to anyone"  31st May 2022      True
# 23169             "It was immaculately clean"  23rd May 2022      True
# 23170  "lost all of our money with no refund"  20th May 2022      True
#
#                                                   Review    Aircraft  \
# 23166   Bangkok to Tokyo. I’ve flown many low cost ai...         NaN
# 23167    Avoid at all costs. I booked flights to go f...         NaN
# 23168    Flight was leaving at 23.15 and after an hou...         NaN
# 23169   Zipair is JAL’s budget airline. They don’t ha...  Dreamliner
# 23170    They lied about connection in Narita and we ...         NaN
#
#       Type Of Traveller       Seat Type  ... Cabin Staff Service  \
# 23166    Couple Leisure   Economy Class  ...                 1.0
# 23167      Solo Leisure   Economy Class  ...                 NaN
# 23168          Business   Economy Class  ...                 4.0
# 23169          Business  Business Class  ...                 4.0
# 23170      Solo Leisure   Economy Class  ...                 NaN
#
#       Food & Beverages  Ground Service  Inflight Entertainment  \
# 23166              NaN             1.0                     1.0
# 23167              NaN             NaN                     NaN
# 23168              2.0             1.0                     NaN
# 23169              3.0             1.0                     2.0
# 23170              NaN             1.0                     NaN
#
#        Wifi & Connectivity  Value For Money  Recommended  length  \
# 23166                  1.0              1.0           no     803
# 23167                  NaN              1.0           no     777
# 23168                  NaN              2.0           no     906
# 23169                  5.0              5.0          yes    3109
# 23170                  NaN              1.0           no     294
#
#                                                   tokens num_tokens
# 23166  [bangkok, to, tokyo, i, ve, flown, many, low, ...        140
# 23167  [avoid, at, all, costs, i, booked, flights, to...        139
# 23168  [flight, was, leaving, at, and, after, an, hou...        163
# 23169  [zipair, is, jal, s, budget, airline, they, do...        584
# 23170  [they, lied, about, connection, in, narita, an...         52
#
# [5 rows x 23 columns]

# %%
from collections import Counter # Importing Counter from Collections
tokens = tokenize("She likes my cats and my cats like my sofa.")
testcount= Counter(tokens) # Counting tokens
print(testcount)
# Out:
# Counter({'my': 3, 'cats': 2, 'She': 1, 'likes': 1, 'and': 1, 'like': 1, 'sofa': 1})

# %% [markdown]
# # Adding New Data to the Current Count

# %%
# Adding New Data to the Current Count
more_tokens = tokenize("She likes dogs and cats.")
testcount.update(more_tokens)
print(testcount)
# Out:
# Counter({'my': 3, 'cats': 3, 'She': 2, 'likes': 2, 'and': 2, 'like': 1, 'sofa': 1, 'dogs': 1})

# %% [markdown]
# # Counting Word Repetitions

# %%
# Counting the Word Repetations
counter = Counter()
df['tokens'].map(counter.update)
print(counter.most_common(5))
# Out:
# [('the', 142455), ('to', 109481), ('and', 90541), ('i', 67475), ('a', 60567)]

# %% [markdown]
# # Using Word Frequency in Its Own DataFrame for Analysis

# %%
# Using word frequency in it’s own dataframe for analysis
freq_df = pd.DataFrame.from_dict(counter, orient='index', columns=['freq']) 
freq_df = freq_df.query('freq >= 1') # Use it to Prevent Worlds that are infrequent
freq_df.index.name = 'token'

# %%
# Let,s sort Based on Frequency and display
freq_df = freq_df.sort_values('freq', ascending=False)
freq_df.head(10)
# Out:
#           freq
# token
# the     142455
# to      109481
# and      90541
# i        67475
# a        60567
# was      59953
# flight   42590
# in       41912
# for      37611
# of       37526

# %%
# Printing the Statistical Data
freq_df.describe()Bar Chart
# Out:
#                 freq
# count   37235.000000
# mean       80.615550
# std      1419.516284
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%         7.000000
# max    142455.000000

# %% [markdown]
# # Bar Chart

# %%
#bar chart 
ax = freq_df.head(15).plot(kind='barh', width=0.95, figsize=(12,8)) # Only for Top 15 Words 
ax.invert_yaxis() 
ax.set(xlabel='Frequency', ylabel='Token', title='Top Words') # Legend
# Out:
# [Text(0.5, 0, 'Frequency'), Text(0, 0.5, 'Token'), Text(0.5, 1.0, 'Top Words')]

# %% [markdown]
# # Installing Wordcloud Package

# %%
# Installing Wordcloud Package
# !pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in /Users/srijanagella/anaconda3/lib/python3.11/site-packages (1.9.3)
# Requirement already satisfied: numpy>=1.6.1 in /Users/srijanagella/anaconda3/lib/python3.11/site-packages (from wordcloud) (1.24.3)
# Requirement already satisfied: pillow in /Users/srijanagella/anaconda3/lib/python3.11/site-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: matplotlib in /Users/srijanagella/anaconda3/lib/python3.11/site-packages (from wordcloud) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/srijanagella/anaconda3/lib/python3.11/site-packages (from matplotlib->wordcloud) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/srijanagella/anaconda3/lib/python3.11/site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/srijanagella/anaconda3/lib/python3.11/site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/srijanagella/anaconda3/lib/python3.11/site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/srijanagella/anaconda3/lib/python3.11/site-packages (from matplotlib->wordcloud) (23.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /Users/srijanagella/anaconda3/lib/python3.11/site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/srijanagella/anaconda3/lib/python3.11/site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/srijanagella/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %% [markdown]
# # Creating a Word Cloud

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud  # Import WordCloud class from the wordcloud library
wc = WordCloud(background_color='Black', width = 300, height=300, max_words=100, margin=2) # Giving BackGround Colour .
wc.fit_words(freq_df['freq'].to_dict() )
plt.figure(figsize = (8, 8), facecolor = None) # Giving fig Size
plt.imshow(wc)
plt.axis("off")
plt.tight_layout(pad = 0)
plt.show()

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd # Import pandas library with alias pd

# %%
import pandas as pd
df = pd.read_csv('/Users/srijanagella/Documents/un-general-debates-blueprint.csv') # Read the CSV file into a DataFrame, replace the path with your correct path

# %%
df.head(20)
# Out:
#     session  year country                     country_name  \
# 0        25  1970     ALB                          Albania
# 1        25  1970     ARG                        Argentina
# 2        25  1970     AUS                        Australia
# 3        25  1970     AUT                          Austria
# 4        25  1970     BEL                          Belgium
# 5        25  1970     BLR                          Belarus
# 6        25  1970     BOL  Bolivia, Plurinational State of
# 7        25  1970     BRA                           Brazil
# 8        25  1970     CAN                           Canada
# 9        25  1970     CMR                         Cameroon
# 10       25  1970     COG                            Congo
# 11       25  1970     COL                         Colombia
# 12       25  1970     CRI                       Costa Rica
# 13       25  1970     CUB                             Cuba
# 14       25  1970     DOM               Dominican Republic
# ...

# %%
df = df.sample(frac=0.2)# Assuming you have a DataFrame named df
# Sample 20% of the rows

# %%
df.columns # Display column names
df.dtypes # Display data types of columns
df.info # Display concise information about the DataFrame
# Out:
# <bound method DataFrame.info of       session  year country                     country_name  \
# 6138       63  2008     TUV                           Tuvalu
# 6084       63  2008     MUS                        Mauritius
# 5581       61  2006     AGO                           Angola
# 260        27  1972     MLI                             Mali
# 1259       35  1980     BHS                          Bahamas
# ...       ...   ...     ...                              ...
# 1843       39  1984     BDI                          Burundi
# 910        32  1977     NER                            Niger
# 3981       52  1997     GHA                            Ghana
# 314        28  1973     ARG                        Argentina
# 6407       65  2010     FSM  Micronesia, Federated States of
#
#                             speaker                      position  \
# 6138                 Apisai Ielemia                Prime Minister
# 6084                Somduth Soborun             UN Representative
# ...

# %%
df.describe() # Display descriptive statistics for numeric columns in the DataFrame
# Out:
#            session         year
# count  1501.000000  1501.000000
# mean     49.868088  1994.868088
# std      12.740170    12.740170
# min      25.000000  1970.000000
# 25%      40.000000  1985.000000
# 50%      51.000000  1996.000000
# 75%      61.000000  2006.000000
# max      70.000000  2015.000000

# %%
df['length'] = df['text'].str.len() # Add a new column 'length' to the DataFrame containing the length of each 'text' element
df.describe() # Display descriptive statistics for the 'length' column
# Out:
#            session         year        length
# count  1501.000000  1501.000000   1501.000000
# mean     49.868088  1994.868088  17900.932712
# std      12.740170    12.740170   7767.170018
# min      25.000000  1970.000000   2362.000000
# 25%      40.000000  1985.000000  12067.000000
# 50%      51.000000  1996.000000  16463.000000
# 75%      61.000000  2006.000000  22390.000000
# max      70.000000  2015.000000  60437.000000

# %%
df.describe(include='O') # Display descriptive statistics for object (string) columns in the DataFrame
# Out:
#        country country_name                speaker  \
# count     1501         1501                   1495
# unique     199          199                   1369
# top        TUN      Tunisia  Joseph Kabila Kabange
# freq        17           17                      4
#
#                             position  \
# count                            920
# unique                            35
# top     Minister for Foreign Affairs
# freq                             368
#
#                                                      text
# count                                                1501
# unique                                               1501
# top     Standing before the \nAssembly for the first t...
# freq                                                    1

# %%
df.isna().sum() # Display the count of missing values in each column
# Out:
# session           0
# year              0
# country           0
# country_name      0
# speaker           6
# position        581
# text              0
# length            0
# dtype: int64

# %%
df['speaker'].fillna('unknown', inplace=True)
df['position'].fillna('unknown', inplace=True) # Fill missing values in 'speaker' and 'position' columns with 'unknown'
df.isna().sum() # Display the count of missing values after filling NaN values
# Out:
# session         0
# year            0
# country         0
# country_name    0
# speaker         0
# position        0
# text            0
# length          0
# dtype: int64

# %%
df['speaker'] = df['speaker'].str.upper()
df['position'] = df['position'].str.upper()
df['text'] = df['text'].str.upper() # Convert 'speaker', 'position', and 'text' columns to uppercase
df[df['speaker'].str.contains('BUSH')] # Filter DataFrame rows where 'speaker' column contains 'BUSH'
# Out:
#       session  year country   country_name          speaker   position  \
# 3207       47  1992     USA  United States  MR. GEORGE BUSH  PRESIDENT
# 4814       56  2001     USA  United States   GEORGE W. BUSH  PRESIDENT
# 3038       46  1991     USA  United States      GEORGE BUSH  PRESIDENT
#
#                                                    text  length
# 3207  FORTY-SEVEN YEARS AGO I WAS A YOUNG MAN OF 21,...   21105
# 4814  ﻿WE MEET IN A HALL DEVOTED TO\nPEACE; IN A CIT...   14724
# 3038  ﻿I AM HONOURED TO SPEAK WITH YOU AS YOU OPEN T...   15555

# %%
df[df['speaker'].str.contains('BUSH')] # Filter DataFrame rows where 'speaker' column contains 'BUSH'
df['length'].plot() # Plot the 'length' column
# Out:
# <Axes: >

# %%
df['length'].plot(kind='box', vert=False) # Plot a box plot for the 'length' column
# Out:
# <Axes: >

# %%
df['length'].plot(kind='hist', bins=30) # Plot a histogram for the 'length' column with 30 bins
# Out:
# <Axes: ylabel='Frequency'>

# %%
import seaborn as sns # Import seaborn library with alias sns
where = df['country'].isin(['USA', 'FRA', 'GBR', 'CHN', 'RUS']) # Filter DataFrame rows where 'country' is in ['USA', 'FRA', 'GBR', 'CHN', 'RUS']
g = sns.catplot(data=df[where], x="country", y="length", kind='box') # Create a box plot using seaborn for 'country' vs 'length'
g.fig.set_size_inches(10, 8)
# Out:
# /Users/srijanagella/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
import regex as re # Import regex library with alias re
def tokenize(text):
    return re.findall(r'[\w-]*[a-z|A-Z][\w-]*', text) # Define a function 'tokenize' to extract words from text

# %%
testtext = "Let's defeat SARS-CoV-2 together in 2020! www.cdc.gov"  # Test the 'tokenize' function on a sample text
testtokens = tokenize(testtext)
print(testtokens)
# Out:
# ['Let', 's', 'defeat', 'SARS-CoV-2', 'together', 'in', 'www', 'cdc', 'gov']

# %%
import nltk  # Import nltk library
nltk.download('stopwords')  # Download nltk stopwords
stopwords = set(nltk.corpus.stopwords.words('english'))  # Get a set of English stopwords
print(stopwords)
# Out:
# {'ours', 'mustn', 'yours', 'itself', 'why', "should've", 'where', 'under', "isn't", 'been', 'has', 'having', "don't", 'while', 'you', 'was', 'few', 'again', 'aren', 'against', 'are', 'doesn', 'don', "you're", "mustn't", 're', 'other', 'over', 'an', "aren't", 'on', 'being', 'haven', 'and', 'she', "shan't", 'that', 'shan', 'wouldn', 'its', 'him', 'they', 'which', 'my', 'them', 'now', "it's", "you'll", 'by', 'because', 'do', "doesn't", 'into', 'didn', "she's", 'me', 'very', 'but', 'for', "couldn't", 'off', 'so', 'below', 'couldn', 'should', 'not', "won't", 'doing', 'were', 'he', 'weren', 'myself', 'then', 'wasn', 'above', 'yourselves', 'the', 'after', 'all', 'will', 'd', 'same', 'only', 'most', 'hasn', 'who', "hadn't", 'your', 'theirs', 'or', 'this', 'these', "didn't", 'be', 'no', 'in', 'ourselves', 'to', 'as', 'through', 'here', 'have', 'more', 'too', 'ain', 'yourself', 'once', 've', 'whom', 'any', 'hadn', "needn't", 'we', 'themselves', 'down', 'both', 'am', 'is', 's', 'ma', 'it', "mig
# ...

# %%
def remove_stop(tokens):
    return [t for t in tokens if t.lower() not in stopwords] # Define a function 'remove_stop' to remove stopwords from a list of tokens
cleantokens= remove_stop(testtokens)  # Test the 'remove_stop' function on cleaned tokens
print(cleantokens)
# Out:
# ['Let', 'defeat', 'SARS-CoV-2', 'together', 'www', 'cdc', 'gov']

# %%
pipeline = [str.lower, tokenize, remove_stop]  # Define a pipeline of functions for text preparation
def prepare(text, pipeline):    # Define a function 'prepare' to apply the pipeline to a text
    tokens = text
    for fun in pipeline:
        tokens = fun(tokens)
        return tokens

# %%
df['tokens'] = df['text'].apply(prepare, pipeline=pipeline)

# %%
df['num_tokens'] = df['tokens'].map(len)  # Apply the 'prepare' function to the 'text' column and create new 'tokens' and 'num_tokens' columns
df.tail()   # Display the last 5 rows of the DataFrame
# Out:
#       session  year country                     country_name        speaker  \
# 1843       39  1984     BDI                          Burundi      NZEYIMANA
# 910        32  1977     NER                            Niger         ADAMOU
# 3981       52  1997     GHA                            Ghana  KWAMENA AHWOI
# 314        28  1973     ARG                        Argentina         VIGNES
# 6407       65  2010     FSM  Micronesia, Federated States of   ALIK L. ALIK
#
#                           position  \
# 1843                       UNKNOWN
# 910                        UNKNOWN
# 3981  MINISTER FOR FOREIGN AFFAIRS
# 314                        UNKNOWN
# 6407                VICE-PRESIDENT
#
#                                                    text  length  \
# 1843  ﻿ONCE AGAIN I AM HONOURED TO HEAD THE DELEGATI...   27918
# 910   ﻿213.\tTHE THIRTY-SECOND SESSION OF THE UNITED...   26832
# 3981  ﻿THE DELEGATION OF GHANA\nCONGRATULATES HIS EX...   17942
# ...

# %%
from collections import Counter # Import Counter class from collections module
tokens = tokenize("She likes my cats and my cats like my sofa.")  # Test the Counter class on a sample list of tokens
testcount= Counter(tokens)
print(testcount)
# Out:
# Counter({'my': 3, 'cats': 2, 'She': 1, 'likes': 1, 'and': 1, 'like': 1, 'sofa': 1})

# %%
more_tokens = tokenize("She likes dogs and cats.") # Update the Counter with more tokens
testcount.update(more_tokens)
print(testcount)
# Out:
# Counter({'my': 3, 'cats': 3, 'She': 2, 'likes': 2, 'and': 2, 'like': 1, 'sofa': 1, 'dogs': 1})

# %%
counter = Counter()  # Create a Counter for all tokens in the 'tokens' column
df['tokens'].map(counter.update)
print(counter.most_common(5)) # Display the 5 most common tokens
# Out:
# [(' ', 4092190), ('e', 2759931), ('t', 2184379), ('i', 1772693), ('n', 1771406)]

# %%
# Create a DataFrame 'freq_df' from the Counter, filter tokens with frequency greater than or equal to 1
freq_df = pd.DataFrame.from_dict(counter,orient='index', columns=['freq']) 
freq_df = freq_df.query('freq >= 1')
freq_df.index.name = 'token'

# %%
freq_df = freq_df.sort_values('freq', ascending=False)
freq_df.head(10)  # Display the top 10 tokens based on frequency
# Out:
#           freq
# token
#        4092190
# e      2759931
# t      2184379
# i      1772693
# n      1771406
# o      1765904
# a      1740145
# s      1352093
# r      1343075
# h       954053

# %%
freq_df.describe() # Display descriptive statistics for the 'freq' column in 'freq_df'
# Out:
#                freq
# count  1.650000e+02
# mean   1.628442e+05
# std    5.264568e+05
# min    1.000000e+00
# 25%    2.000000e+00
# 50%    1.500000e+01
# 75%    7.405000e+03
# max    4.092190e+06

# %%
# Plot a horizontal bar chart for the top 15 tokens
ax = freq_df.head(15).plot(kind='barh', width=0.95, figsize=(12,8))
ax.invert_yaxis()
ax.set(xlabel='Frequency', ylabel='Token', title='Top Words')
# Out:
# [Text(0.5, 0, 'Frequency'), Text(0, 0.5, 'Token'), Text(0.5, 1.0, 'Top Words')]

# %%
# Import WordCloud class from wordcloud module and pyplot from matplotlib
from wordcloud import WordCloud
from matplotlib import pyplot as plt
text = df.query("year==2015 and country=='USA'")['text'].values[0]  # Query the 'text' column for specific conditions

# %%
# !pip install wordcloud

# %%
from wordcloud import WordCloud
from matplotlib import pyplot as plt
text = df.query("year==1977 and country=='NER'")['text'].values[0]
plt.figure(figsize=(14, 7))  # Display the WordCloud using matplotlib
wc = WordCloud(max_words=100, stopwords=stopwords)  
wc.generate(text)  # Generate a WordCloud for the selected text
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
import matplotlib.pyplot as plt

# %%
# Specify conditions
conditions = (df['year'] == 1977) & (df['country'] == 'NER')  # Specify conditions for filtering the DataFrame

# Check if there is data for the specified conditions
if df[conditions].empty:
    print("No data found for the given conditions.")
else:
    # Extract text for the specified conditions
    text = df[conditions]['text'].values[0]

    # Create and generate the word cloud
    wc = WordCloud(background_color='white', width=300, height=300, max_words=100, margin=2)
    wc.generate_from_text(text)

    # Display the word cloud
    plt.figure(figsize=(8, 8), facecolor=None)
    plt.imshow(wc)
    plt.axis("off")
    plt.tight_layout(pad=0)
    plt.show()
